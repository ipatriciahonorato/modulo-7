# %% [markdown]
# <h2><center> Pré-processamento dos dados de voo selecionados e agregados </center></h2>

# %% [markdown]
# ### 1. Importação de bliotecas

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### 2. Carregamento do arquivo de dados

# %%
flights_combined_data_curated = pd.read_parquet('flights_combined_data_curated.parquet')

# %%
flights_combined_data_curated
# Out:
#          recording_time  dateDay-1  dateMonth-1  dateYear-1  phaseOfFlight-1  \
# 0                     0        NaN          NaN         NaN              0.0
# 1                    50        NaN          NaN         NaN              NaN
# 2                   100        NaN          NaN         NaN              0.0
# 3                   150       28.0          2.0      2023.0              NaN
# 4                   200        NaN          NaN         NaN              0.0
# ...                 ...        ...          ...         ...              ...
# 7376848         3965800       28.0          2.0      2023.0              NaN
# 7376849         3965850        NaN          NaN         NaN              0.0
# 7376850         3965900        NaN          NaN         NaN              NaN
# 7376851         3965950        NaN          NaN         NaN              0.0
# 7376852         3966000        NaN          NaN         NaN              NaN
#
# ...

# %%
flights_combined_data_curated.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7376853 entries, 0 to 7376852
# Data columns (total 52 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   recording_time             int32
#  1   dateDay-1                  float32
#  2   dateMonth-1                float32
#  3   dateYear-1                 float32
#  4   phaseOfFlight-1            float32
#  5   message0418DAA-1           float32
#  6   message0422DAA-1           float32
#  7   amscHprsovDrivF-1a         float32
#  8   amscHprsovDrivF-1b         float32
#  9   amscHprsovDrivF-2b         float32
#  10  amscPrsovDrivF-1a          float32
#  11  amscPrsovDrivF-1b          float32
#  12  amscPrsovDrivF-2b          float32
#  13  basBleedLowPressF-1a       float32
#  14  basBleedLowPressF-2b       float32
#  15  basBleedLowTempF-1a        float32
#  16  basBleedLowTempF-2b        float32
#  17  basBleedOverPressF-1a      float32
#  18  basBleedOverPressF-2b      float32
# ...

# %%
flights_combined_data_curated.describe()
# Out:
#        recording_time  dateDay-1  dateMonth-1     dateYear-1  phaseOfFlight-1  \
# count    7.376853e+06   368838.0     368838.0  368838.000000     3.689031e+06
# mean     1.983000e+06       28.0          2.0    2022.997803     8.674465e-01
# std      1.144900e+06        0.0          0.0       0.000000     9.169106e-01
# min      0.000000e+00       28.0          2.0    2023.000000     0.000000e+00
# 25%      9.915000e+05       28.0          2.0    2023.000000     0.000000e+00
# 50%      1.983000e+06       28.0          2.0    2023.000000     1.000000e+00
# 75%      2.974500e+06       28.0          2.0    2023.000000     2.000000e+00
# max      3.966000e+06       28.0          2.0    2023.000000     2.000000e+00
#
#        message0418DAA-1  message0422DAA-1  amscHprsovDrivF-1a  \
# count          368838.0          368838.0           1843911.0
# mean                0.0               0.0                 0.0
# std                 0.0               0.0                 0.0
# ...

# %%
for column in flights_combined_data_curated.columns:
    print("Column: ", column)
    try:
        print(flights_combined_data_curated[column].value_counts()[0])
    except KeyError:
        print(f"Column {column} not found in flights_combined_data_curated")

plt.show()
# Out:
# Column:  recording_time
# 93
# Column:  dateDay-1
# Column dateDay-1 not found in flights_combined_data_curated
# Column:  dateMonth-1
# Column dateMonth-1 not found in flights_combined_data_curated
# Column:  dateYear-1
# Column dateYear-1 not found in flights_combined_data_curated
# Column:  phaseOfFlight-1
# 1827636
# Column:  message0418DAA-1
# 368838
# Column:  message0422DAA-1
# 368838
# Column:  amscHprsovDrivF-1a
# 1843911
# Column:  amscHprsovDrivF-1b
# 1843911
# Column:  amscHprsovDrivF-2b
# 1843911
# Column:  amscPrsovDrivF-1a
# 1843911
# Column:  amscPrsovDrivF-1b
# 1843911
# Column:  amscPrsovDrivF-2b
# 1843911
# Column:  basBleedLowPressF-1a
# 1843911
# Column:  basBleedLowPressF-2b
# 1843911
# Column:  basBleedLowTempF-1a
# 1843911
# Column:  basBleedLowTempF-2b
# 1843911
# Column:  basBleedOverPressF-1a
# 1843911
# Column:  basBleedOverPressF-2b
# 1843911
# Column:  basBleedOverTempF-1a
# 1843911
# Column:  basBleedOverTempF-2b
# 1843911
# Column:  bleedFavTmCmd-1a
# ...
