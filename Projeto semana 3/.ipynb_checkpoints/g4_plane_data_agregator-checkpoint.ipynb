# %% [markdown]
# <h2><center> Agregação e seleção de séries de dados de arquivos parquet com dados de telemetria de voos</center></h2>

# %% [markdown]
# ### 1. Importação de bliotecas

# %%
import pandas as pd
import os

# %% [markdown]
# ### 2. Carregamento de arquivos de dados parquet para dataframes

# %%
file_path = "airplane_data/"

parquet_files = []
for file in os.listdir(file_path):
    if file.endswith('.parquet'):
        parquet_files.append(file)

# Loop through the files and read each Parquet file
for file_name in parquet_files:
    flights_combined_data = pd.read_parquet(file_path + file_name)
    print("Loading file: " + file_name)
# Out:
# Loading file: TCRF_ARCHIVE_06120089_20230227102830.parquet
# Loading file: TCRF_ARCHIVE_06120089_20230227120730.parquet
# Loading file: TCRF_ARCHIVE_06120089_20230227172631.parquet
# Loading file: TCRF_ARCHIVE_06120089_20230227194931.parquet
# Loading file: TCRF_ARCHIVE_06120089_20230227221531.parquet
# Loading file: TCRF_ARCHIVE_06120089_20230228005831.parquet
# Loading file: TCRF_ARCHIVE_06120089_20230228043131.parquet
# Loading file: TCRF_ARCHIVE_06120089_20230228080931.parquet
# Loading file: TCRF_ARCHIVE_06120089_20230228101134.parquet
# Loading file: TCRF_ARCHIVE_06120089_20230228125231.parquet

# %% [markdown]
# ### 3. Visualização de informações descritivas do dataframe de dados agregados crus

# %%
flights_combined_data
# Out:
#        recording_time  aircraftSerNum-1  amscChBasHealthStatus-1b  \
# 0                   0               NaN                       NaN
# 1                  50               NaN                       0.0
# 2                 100               NaN                       NaN
# 3                 150           20089.0                       NaN
# 4                 200               NaN                       NaN
# ...               ...               ...                       ...
# 79316         3965800           20089.0                       NaN
# 79317         3965850               NaN                       NaN
# 79318         3965900               NaN                       0.0
# 79319         3965950               NaN                       NaN
# 79320         3966000               NaN                       NaN
#
#        amscChBasHealthStatus-1a  amscChBasHealthStatus-2b  amscHprsovDrivF-1a  \
# 0                           NaN                       NaN                 NaN
# 1                           0.0                       0.0                 0.0
# 2                           NaN                       NaN                 NaN
# 3                           NaN                       NaN                 NaN
# 4                           NaN                       NaN                 NaN
# ...                         ...                       ...                 ...
# 79316                       NaN                       NaN                 NaN
# 79317                       NaN                       NaN                 NaN
# 79318                       0.0                       0.0                 0.0
# 79319                       NaN                       NaN                 NaN
# 79320                       NaN                       NaN                 NaN
#
#        amscHprsovDrivF-1b  amscHprsovDrivF-2b  amscPrsovDrivF-1a  \
# 0                     NaN                 NaN                NaN
# 1                     0.0                 0.0                0.0
# 2                     NaN                 NaN                NaN
# 3                     NaN                 NaN                NaN
# 4                     NaN                 NaN                NaN
# ...                   ...                 ...                ...
# 79316                 NaN                 NaN                NaN
# 79317                 NaN                 NaN                NaN
# 79318                 0.0                 0.0                0.0
# 79319                 NaN                 NaN                NaN
# 79320                 NaN                 NaN                NaN
#
#        amscPrsovDrivF-1b  ...  message0418DAA-1  message0422DAA-1  \
# 0                    NaN  ...               NaN               NaN
# 1                    0.0  ...               NaN               NaN
# 2                    NaN  ...               NaN               NaN
# 3                    NaN  ...               0.0               0.0
# 4                    NaN  ...               NaN               NaN
# ...                  ...  ...               ...               ...
# 79316                NaN  ...               0.0               0.0
# 79317                NaN  ...               NaN               NaN
# 79318                0.0  ...               NaN               NaN
# 79319                NaN  ...               NaN               NaN
# 79320                NaN  ...               NaN               NaN
#
#        messageInhibitPhases-1  phaseOfFlight-1  phaseOfFlightNavigation-1  \
# 0                         1.0              0.0                        2.0
# 1                         NaN              NaN                        NaN
# 2                         1.0              0.0                        2.0
# 3                         NaN              NaN                        NaN
# 4                         1.0              0.0                        2.0
# ...                       ...              ...                        ...
# 79316                     NaN              NaN                        NaN
# 79317                     1.0              0.0                        2.0
# 79318                     NaN              NaN                        NaN
# 79319                     1.0              0.0                        2.0
# 79320                     NaN              NaN                        NaN
#
#        sfyBasFaultWord1Bit13-1a  sfyBasFaultWord1Bit13-2b  timeHours-1  \
# 0                           NaN                       NaN          NaN
# 1                           0.0                       0.0          NaN
# 2                           NaN                       NaN          NaN
# 3                           NaN                       NaN         11.0
# 4                           NaN                       NaN          NaN
# ...                         ...                       ...          ...
# 79316                       NaN                       NaN         12.0
# 79317                       NaN                       NaN          NaN
# 79318                       0.0                       0.0          NaN
# 79319                       NaN                       NaN          NaN
# 79320                       NaN                       NaN          NaN
#
#        timeMinutes-1  timeSeconds-1
# 0                NaN            NaN
# 1                NaN            NaN
# 2                NaN            NaN
# 3               41.0           13.0
# 4                NaN            NaN
# ...              ...            ...
# 79316           47.0           18.0
# 79317            NaN            NaN
# 79318            NaN            NaN
# 79319            NaN            NaN
# 79320            NaN            NaN
#
# [79321 rows x 93 columns]

# %%
flights_combined_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79321 entries, 0 to 79320
# Data columns (total 93 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   recording_time                79321 non-null  int64
#  1   aircraftSerNum-1              3966 non-null   float64
#  2   amscChBasHealthStatus-1b      19827 non-null  float64
#  3   amscChBasHealthStatus-1a      19827 non-null  float64
#  4   amscChBasHealthStatus-2b      19827 non-null  float64
#  5   amscHprsovDrivF-1a            19827 non-null  float64
#  6   amscHprsovDrivF-1b            19827 non-null  float64
#  7   amscHprsovDrivF-2b            19827 non-null  float64
#  8   amscPrsovDrivF-1a             19827 non-null  float64
#  9   amscPrsovDrivF-1b             19827 non-null  float64
#  10  amscPrsovDrivF-2b             19827 non-null  float64
#  11  basBleedLowPressF-1a          19827 non-null  float64
#  12  basBleedLowPressF-2b          19827 non-null  float64
#  13  basBleedLowTempF-1a           19827 non-null  float64
#  14  basBleedLowTempF-2b           19827 non-null  float64
#  15  basBleedOverPressF-1a         19827 non-null  float64
#  16  basBleedOverPressF-2b         19827 non-null  float64
#  17  basBleedOverTempF-1a          19827 non-null  float64
#  18  basBleedOverTempF-2b          19827 non-null  float64
#  19  bleedAcsBleedConfigStatus-1b  39667 non-null  float64
#  20  bleedAcsBleedConfigStatus-2b  39667 non-null  float64
#  21  bleedFavTmCmd-1a              19827 non-null  float64
#  22  bleedFavTmCmd-1b              19827 non-null  float64
#  23  bleedFavTmCmd-2a              19827 non-null  float64
#  24  bleedFavTmCmd-2b              19827 non-null  float64
#  25  bleedFavTmFbk-1a              19827 non-null  float64
#  26  bleedFavTmFbk-1b              19827 non-null  float64
#  27  bleedFavTmFbk-2b              19827 non-null  float64
#  28  bleedHprsovCmdStatus-1a       39667 non-null  float64
#  29  bleedHprsovCmdStatus-1b       39667 non-null  float64
#  30  bleedHprsovCmdStatus-2a       39667 non-null  float64
#  31  bleedHprsovCmdStatus-2b       39667 non-null  float64
#  32  bleedHprsovOpPosStatus-1a     39667 non-null  float64
#  33  bleedHprsovOpPosStatus-1b     39667 non-null  float64
#  34  bleedHprsovOpPosStatus-2a     39667 non-null  float64
#  35  bleedHprsovOpPosStatus-2b     39667 non-null  float64
#  36  bleedMonPress-1a              19827 non-null  float64
#  37  bleedMonPress-1b              19827 non-null  float64
#  38  bleedMonPress-2a              19827 non-null  float64
#  39  bleedMonPress-2b              19827 non-null  float64
#  40  bleedOnStatus-1a              39667 non-null  float64
#  41  bleedOnStatus-1b              39667 non-null  float64
#  42  bleedOnStatus-2b              39667 non-null  float64
#  43  bleedOutTemp-1a               19827 non-null  float64
#  44  bleedOutTemp-1b               19827 non-null  float64
#  45  bleedOutTemp-2a               19827 non-null  float64
#  46  bleedOutTemp-2b               19827 non-null  float64
#  47  bleedOutTempTarget-1a         19827 non-null  float64
#  48  bleedOutTempTarget-1b         19827 non-null  float64
#  49  bleedOutTempTarget-2b         19827 non-null  float64
#  50  bleedOverpressCas-1a          19827 non-null  float64
#  51  bleedOverpressCas-2a          19827 non-null  float64
#  52  bleedOverpressCas-2b          19827 non-null  float64
#  53  bleedPrecoolDiffPress-1a      19827 non-null  float64
#  54  bleedPrecoolDiffPress-1b      19827 non-null  float64
#  55  bleedPrecoolDiffPress-2a      19827 non-null  float64
#  56  bleedPrecoolDiffPress-2b      19827 non-null  float64
#  57  bleedPrsovClPosStatus-1a      39667 non-null  float64
#  58  bleedPrsovClPosStatus-2a      39667 non-null  float64
#  59  bleedPrsovFbk-1a              19827 non-null  float64
#  60  bleedPrsovFbk-1b              19827 non-null  float64
#  61  bleedPrsovFbk-2b              19827 non-null  float64
#  62  bleedPrsovOpPosStatus-1a      39667 non-null  float64
#  63  bleedPrsovOpPosStatus-1b      39667 non-null  float64
#  64  bleedPrsovOpPosStatus-2a      39667 non-null  float64
#  65  bleedPrsovOpPosStatus-2b      39667 non-null  float64
#  66  bleedPrsovTmCmd-1a            19827 non-null  float64
#  67  bleedPrsovTmCmd-1b            19827 non-null  float64
#  68  bleedPrsovTmCmd-2a            19827 non-null  float64
#  69  bleedPrsovTmCmd-2b            19827 non-null  float64
#  70  bleedSingleOperation-1a       39667 non-null  float64
#  71  bleedSingleOperation-2b       39667 non-null  float64
#  72  bleedSwPress-1a               19827 non-null  float64
#  73  bleedSwPress-1b               19827 non-null  float64
#  74  bleedSwPress-2a               19827 non-null  float64
#  75  bleedSwPress-2b               19827 non-null  float64
#  76  correctedCoreSpeed-1a         79321 non-null  float64
#  77  correctedCoreSpeed-3a         79321 non-null  float64
#  78  correctedN1Speed-1a           79321 non-null  float64
#  79  correctedN1Speed-3a           79321 non-null  float64
#  80  dateDay-1                     3966 non-null   float64
#  81  dateMonth-1                   3966 non-null   float64
#  82  dateYear-1                    3966 non-null   float64
#  83  message0418DAA-1              3966 non-null   float64
#  84  message0422DAA-1              3966 non-null   float64
#  85  messageInhibitPhases-1        39667 non-null  float64
#  86  phaseOfFlight-1               39667 non-null  float64
#  87  phaseOfFlightNavigation-1     39667 non-null  float64
#  88  sfyBasFaultWord1Bit13-1a      19827 non-null  float64
#  89  sfyBasFaultWord1Bit13-2b      19827 non-null  float64
#  90  timeHours-1                   3966 non-null   float64
#  91  timeMinutes-1                 3966 non-null   float64
#  92  timeSeconds-1                 3966 non-null   float64
# dtypes: float64(92), int64(1)
# memory usage: 56.3 MB

# %%
flights_combined_data.describe()
# Out:
#        recording_time  aircraftSerNum-1  amscChBasHealthStatus-1b  \
# count    7.932100e+04            3966.0                   19827.0
# mean     1.983000e+06           20089.0                       0.0
# std      1.144907e+06               0.0                       0.0
# min      0.000000e+00           20089.0                       0.0
# 25%      9.915000e+05           20089.0                       0.0
# 50%      1.983000e+06           20089.0                       0.0
# 75%      2.974500e+06           20089.0                       0.0
# max      3.966000e+06           20089.0                       0.0
#
#        amscChBasHealthStatus-1a  amscChBasHealthStatus-2b  amscHprsovDrivF-1a  \
# count                   19827.0                   19827.0             19827.0
# mean                        0.0                       0.0                 0.0
# std                         0.0                       0.0                 0.0
# min                         0.0                       0.0                 0.0
# 25%                         0.0                       0.0                 0.0
# 50%                         0.0                       0.0                 0.0
# 75%                         0.0                       0.0                 0.0
# max                         0.0                       0.0                 0.0
#
#        amscHprsovDrivF-1b  amscHprsovDrivF-2b  amscPrsovDrivF-1a  \
# count             19827.0             19827.0            19827.0
# mean                  0.0                 0.0                0.0
# std                   0.0                 0.0                0.0
# min                   0.0                 0.0                0.0
# 25%                   0.0                 0.0                0.0
# 50%                   0.0                 0.0                0.0
# 75%                   0.0                 0.0                0.0
# max                   0.0                 0.0                0.0
#
#        amscPrsovDrivF-1b  ...  message0418DAA-1  message0422DAA-1  \
# count            19827.0  ...            3966.0            3966.0
# mean                 0.0  ...               0.0               0.0
# std                  0.0  ...               0.0               0.0
# min                  0.0  ...               0.0               0.0
# 25%                  0.0  ...               0.0               0.0
# 50%                  0.0  ...               0.0               0.0
# 75%                  0.0  ...               0.0               0.0
# max                  0.0  ...               0.0               0.0
#
#        messageInhibitPhases-1  phaseOfFlight-1  phaseOfFlightNavigation-1  \
# count            39667.000000     39667.000000               39667.000000
# mean                 4.225628         0.867446                   4.279729
# std                  1.474558         0.916922                   1.676160
# min                  0.000000         0.000000                   1.000000
# 25%                  5.000000         0.000000                   3.000000
# 50%                  5.000000         1.000000                   5.000000
# 75%                  5.000000         2.000000                   5.000000
# max                  6.000000         2.000000                   7.000000
#
#        sfyBasFaultWord1Bit13-1a  sfyBasFaultWord1Bit13-2b  timeHours-1  \
# count                   19827.0                   19827.0  3966.000000
# mean                        0.0                       0.0    11.715835
# std                         0.0                       0.0     0.451073
# min                         0.0                       0.0    11.000000
# 25%                         0.0                       0.0    11.000000
# 50%                         0.0                       0.0    12.000000
# 75%                         0.0                       0.0    12.000000
# max                         0.0                       0.0    12.000000
#
#        timeMinutes-1  timeSeconds-1
# count    3966.000000     3966.00000
# mean       30.816944       29.47882
# std        17.019617       17.31586
# min         0.000000        0.00000
# 25%        16.000000       14.25000
# 50%        33.000000       29.00000
# 75%        45.000000       44.00000
# max        59.000000       59.00000
#
# [8 rows x 93 columns]

# %% [markdown]
# ### 4. Seleção das colunas de interesse para a análise

# %%
# Selecionar apenas essas colunas dos arquivos parquet
filtered_cols = ['recording_time', 'dateDay-1', 'dateMonth-1', 'dateYear-1', 'phaseOfFlight-1',
                 'message0418DAA-1','message0422DAA-1','amscHprsovDrivF-1a', 'amscHprsovDrivF-1b',
                 'amscHprsovDrivF-2b', 'amscPrsovDrivF-1a',
                 'amscPrsovDrivF-1b', 'amscPrsovDrivF-2b',
                 'basBleedLowPressF-1a', 'basBleedLowPressF-2b',
                 'basBleedLowTempF-1a', 'basBleedLowTempF-2b',
                 'basBleedOverPressF-1a', 'basBleedOverPressF-2b',
                 'basBleedOverTempF-1a', 'basBleedOverTempF-2b',
                 'bleedFavTmCmd-1a', 'bleedFavTmCmd-1b',
                 'bleedFavTmCmd-2a', 'bleedFavTmCmd-2b', 'bleedFavTmFbk-1a',
                 'bleedFavTmFbk-1b', 'bleedFavTmFbk-2b', 'bleedHprsovCmdStatus-1a',
                 'bleedHprsovCmdStatus-1b', 'bleedHprsovCmdStatus-2a',
                 'bleedHprsovCmdStatus-2b', 'bleedHprsovOpPosStatus-1a',
                 'bleedHprsovOpPosStatus-1b', 'bleedHprsovOpPosStatus-2a',
                 'bleedHprsovOpPosStatus-2b', 'bleedMonPress-1a',
                 'bleedMonPress-1b', 'bleedMonPress-2a', 'bleedMonPress-2b',
                 'bleedOnStatus-1a', 'bleedOnStatus-1b', 'bleedOnStatus-2b',
                 'bleedOverpressCas-2a', 'bleedOverpressCas-2b',
                 'bleedPrecoolDiffPress-1a', 'bleedPrecoolDiffPress-1b',
                 'bleedPrecoolDiffPress-2a', 'bleedPrecoolDiffPress-2b',
                 'bleedPrsovClPosStatus-1a', 'bleedPrsovClPosStatus-2a',
                 'bleedPrsovFbk-1a']

# %%
print(len(filtered_cols))
# Out:
# 52

# %%
flights_combined_data_curated = []

for df in flights_combined_data:
    columns_exist = True
    for col in filtered_cols:
        if col not in flights_combined_data.columns:
            columns_exist = False
            break
    
    if columns_exist:
        flights_combined_data_curated_df = flights_combined_data[filtered_cols]
        flights_combined_data_curated.append(flights_combined_data_curated_df)

# %%
# Concatenar todos os DataFrames filtrados em um único Df
flights_combined_data_curated = pd.concat(flights_combined_data_curated, ignore_index=True)

# %% [markdown]
# ### 5. Visualização de informações descritivas do dataframe de dados com colunas de interesse

# %%
flights_combined_data_curated.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7376853 entries, 0 to 7376852
# Data columns (total 52 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   recording_time             int64
#  1   dateDay-1                  float64
#  2   dateMonth-1                float64
#  3   dateYear-1                 float64
#  4   phaseOfFlight-1            float64
#  5   message0418DAA-1           float64
#  6   message0422DAA-1           float64
#  7   amscHprsovDrivF-1a         float64
#  8   amscHprsovDrivF-1b         float64
#  9   amscHprsovDrivF-2b         float64
#  10  amscPrsovDrivF-1a          float64
#  11  amscPrsovDrivF-1b          float64
#  12  amscPrsovDrivF-2b          float64
#  13  basBleedLowPressF-1a       float64
#  14  basBleedLowPressF-2b       float64
#  15  basBleedLowTempF-1a        float64
#  16  basBleedLowTempF-2b        float64
#  17  basBleedOverPressF-1a      float64
#  18  basBleedOverPressF-2b      float64
#  19  basBleedOverTempF-1a       float64
#  20  basBleedOverTempF-2b       float64
#  21  bleedFavTmCmd-1a           float64
#  22  bleedFavTmCmd-1b           float64
#  23  bleedFavTmCmd-2a           float64
#  24  bleedFavTmCmd-2b           float64
#  25  bleedFavTmFbk-1a           float64
#  26  bleedFavTmFbk-1b           float64
#  27  bleedFavTmFbk-2b           float64
#  28  bleedHprsovCmdStatus-1a    float64
#  29  bleedHprsovCmdStatus-1b    float64
#  30  bleedHprsovCmdStatus-2a    float64
#  31  bleedHprsovCmdStatus-2b    float64
#  32  bleedHprsovOpPosStatus-1a  float64
#  33  bleedHprsovOpPosStatus-1b  float64
#  34  bleedHprsovOpPosStatus-2a  float64
#  35  bleedHprsovOpPosStatus-2b  float64
#  36  bleedMonPress-1a           float64
#  37  bleedMonPress-1b           float64
#  38  bleedMonPress-2a           float64
#  39  bleedMonPress-2b           float64
#  40  bleedOnStatus-1a           float64
#  41  bleedOnStatus-1b           float64
#  42  bleedOnStatus-2b           float64
#  43  bleedOverpressCas-2a       float64
#  44  bleedOverpressCas-2b       float64
#  45  bleedPrecoolDiffPress-1a   float64
#  46  bleedPrecoolDiffPress-1b   float64
#  47  bleedPrecoolDiffPress-2a   float64
#  48  bleedPrecoolDiffPress-2b   float64
#  49  bleedPrsovClPosStatus-1a   float64
#  50  bleedPrsovClPosStatus-2a   float64
#  51  bleedPrsovFbk-1a           float64
# dtypes: float64(51), int64(1)
# memory usage: 2.9 GB

# %%
flights_combined_data_curated.describe()
# Out:
#        recording_time  dateDay-1  dateMonth-1  dateYear-1  phaseOfFlight-1  \
# count    7.376853e+06   368838.0     368838.0    368838.0     3.689031e+06
# mean     1.983000e+06       28.0          2.0      2023.0     8.674465e-01
# std      1.144900e+06        0.0          0.0         0.0     9.169106e-01
# min      0.000000e+00       28.0          2.0      2023.0     0.000000e+00
# 25%      9.915000e+05       28.0          2.0      2023.0     0.000000e+00
# 50%      1.983000e+06       28.0          2.0      2023.0     1.000000e+00
# 75%      2.974500e+06       28.0          2.0      2023.0     2.000000e+00
# max      3.966000e+06       28.0          2.0      2023.0     2.000000e+00
#
#        message0418DAA-1  message0422DAA-1  amscHprsovDrivF-1a  \
# count          368838.0          368838.0           1843911.0
# mean                0.0               0.0                 0.0
# std                 0.0               0.0                 0.0
# min                 0.0               0.0                 0.0
# 25%                 0.0               0.0                 0.0
# 50%                 0.0               0.0                 0.0
# 75%                 0.0               0.0                 0.0
# max                 0.0               0.0                 0.0
#
#        amscHprsovDrivF-1b  amscHprsovDrivF-2b  ...  bleedOnStatus-2b  \
# count           1843911.0           1843911.0  ...      3.689031e+06
# mean                  0.0                 0.0  ...      9.098999e-01
# std                   0.0                 0.0  ...      2.863251e-01
# min                   0.0                 0.0  ...      0.000000e+00
# 25%                   0.0                 0.0  ...      1.000000e+00
# 50%                   0.0                 0.0  ...      1.000000e+00
# 75%                   0.0                 0.0  ...      1.000000e+00
# max                   0.0                 0.0  ...      1.000000e+00
#
#        bleedOverpressCas-2a  bleedOverpressCas-2b  bleedPrecoolDiffPress-1a  \
# count             1843911.0             1843911.0              1.843911e+06
# mean                    0.0                   0.0              6.677179e-01
# std                     0.0                   0.0              2.672614e-01
# min                     0.0                   0.0             -2.500000e-01
# 25%                     0.0                   0.0              5.937500e-01
# 50%                     0.0                   0.0              6.875000e-01
# 75%                     0.0                   0.0              7.500000e-01
# max                     0.0                   0.0              2.781250e+00
#
#        bleedPrecoolDiffPress-1b  bleedPrecoolDiffPress-2a  \
# count              1.843911e+06              1.843911e+06
# mean               6.689521e-01              5.901328e-01
# std                2.653569e-01              2.277969e-01
# min               -2.500000e-01             -1.250000e-01
# 25%                5.937500e-01              5.625000e-01
# 50%                6.875000e-01              6.250000e-01
# 75%                7.500000e-01              6.875000e-01
# max                2.812500e+00              2.875000e+00
#
#        bleedPrecoolDiffPress-2b  bleedPrsovClPosStatus-1a  \
# count              1.843911e+06              3.689031e+06
# mean               5.901249e-01              6.622633e-02
# std                2.278252e-01              2.486773e-01
# min               -1.250000e-01              0.000000e+00
# 25%                5.625000e-01              0.000000e+00
# 50%                6.250000e-01              0.000000e+00
# 75%                6.875000e-01              0.000000e+00
# max                2.875000e+00              1.000000e+00
#
#        bleedPrsovClPosStatus-2a  bleedPrsovFbk-1a
# count              3.689031e+06      1.843911e+06
# mean               9.010008e-02      1.510177e+02
# std                2.863251e-01      4.254531e+01
# min                0.000000e+00      1.875000e+00
# 25%                0.000000e+00      1.468750e+02
# 50%                0.000000e+00      1.595000e+02
# 75%                0.000000e+00      1.680000e+02
# max                1.000000e+00      2.887500e+02
#
# [8 rows x 52 columns]

# %% [markdown]
# ### 6. Redução de dimensionalidade das series temporais com codificação de dados de float64 para int64

# %%
def convert_columns(df_filtered):
    for coluna in df_filtered.columns:
        if df_filtered[coluna].dtype == 'float64':
            df_filtered[coluna] = df_filtered[coluna].astype('float32')

        if df_filtered[coluna].dtype == 'int64':
            df_filtered[coluna] = df_filtered[coluna].astype('int32')

    return df_filtered

# %%
flights_combined_data_curated = convert_columns(flights_combined_data_curated)

# %%
flights_combined_data_curated
# Out:
#          recording_time  dateDay-1  dateMonth-1  dateYear-1  phaseOfFlight-1  \
# 0                     0        NaN          NaN         NaN              0.0
# 1                    50        NaN          NaN         NaN              NaN
# 2                   100        NaN          NaN         NaN              0.0
# 3                   150       28.0          2.0      2023.0              NaN
# 4                   200        NaN          NaN         NaN              0.0
# ...                 ...        ...          ...         ...              ...
# 7376848         3965800       28.0          2.0      2023.0              NaN
# 7376849         3965850        NaN          NaN         NaN              0.0
# 7376850         3965900        NaN          NaN         NaN              NaN
# 7376851         3965950        NaN          NaN         NaN              0.0
# 7376852         3966000        NaN          NaN         NaN              NaN
#
#          message0418DAA-1  message0422DAA-1  amscHprsovDrivF-1a  \
# 0                     NaN               NaN                 NaN
# 1                     NaN               NaN                 0.0
# 2                     NaN               NaN                 NaN
# 3                     0.0               0.0                 NaN
# 4                     NaN               NaN                 NaN
# ...                   ...               ...                 ...
# 7376848               0.0               0.0                 NaN
# 7376849               NaN               NaN                 NaN
# 7376850               NaN               NaN                 0.0
# 7376851               NaN               NaN                 NaN
# 7376852               NaN               NaN                 NaN
#
#          amscHprsovDrivF-1b  amscHprsovDrivF-2b  ...  bleedOnStatus-2b  \
# 0                       NaN                 NaN  ...               0.0
# 1                       0.0                 0.0  ...               NaN
# 2                       NaN                 NaN  ...               0.0
# 3                       NaN                 NaN  ...               NaN
# 4                       NaN                 NaN  ...               0.0
# ...                     ...                 ...  ...               ...
# 7376848                 NaN                 NaN  ...               NaN
# 7376849                 NaN                 NaN  ...               0.0
# 7376850                 0.0                 0.0  ...               NaN
# 7376851                 NaN                 NaN  ...               0.0
# 7376852                 NaN                 NaN  ...               NaN
#
#          bleedOverpressCas-2a  bleedOverpressCas-2b  bleedPrecoolDiffPress-1a  \
# 0                         NaN                   NaN                       NaN
# 1                         0.0                   0.0                   0.09375
# 2                         NaN                   NaN                       NaN
# 3                         NaN                   NaN                       NaN
# 4                         NaN                   NaN                       NaN
# ...                       ...                   ...                       ...
# 7376848                   NaN                   NaN                       NaN
# 7376849                   NaN                   NaN                       NaN
# 7376850                   0.0                   0.0                   0.03125
# 7376851                   NaN                   NaN                       NaN
# 7376852                   NaN                   NaN                       NaN
#
#          bleedPrecoolDiffPress-1b  bleedPrecoolDiffPress-2a  \
# 0                             NaN                       NaN
# 1                         0.06250                   0.00000
# 2                             NaN                       NaN
# 3                             NaN                       NaN
# 4                             NaN                       NaN
# ...                           ...                       ...
# 7376848                       NaN                       NaN
# 7376849                       NaN                       NaN
# 7376850                   0.03125                   0.03125
# 7376851                       NaN                       NaN
# 7376852                       NaN                       NaN
#
#          bleedPrecoolDiffPress-2b  bleedPrsovClPosStatus-1a  \
# 0                             NaN                       1.0
# 1                         0.00000                       NaN
# 2                             NaN                       1.0
# 3                             NaN                       NaN
# 4                             NaN                       1.0
# ...                           ...                       ...
# 7376848                       NaN                       NaN
# 7376849                       NaN                       1.0
# 7376850                   0.03125                       NaN
# 7376851                       NaN                       1.0
# 7376852                       NaN                       NaN
#
#          bleedPrsovClPosStatus-2a  bleedPrsovFbk-1a
# 0                             1.0               NaN
# 1                             NaN               2.0
# 2                             1.0               NaN
# 3                             NaN               NaN
# 4                             1.0               NaN
# ...                           ...               ...
# 7376848                       NaN               NaN
# 7376849                       1.0               NaN
# 7376850                       NaN               2.0
# 7376851                       1.0               NaN
# 7376852                       NaN               NaN
#
# [7376853 rows x 52 columns]

# %%
flights_combined_data_curated.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7376853 entries, 0 to 7376852
# Data columns (total 52 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   recording_time             int32
#  1   dateDay-1                  float32
#  2   dateMonth-1                float32
#  3   dateYear-1                 float32
#  4   phaseOfFlight-1            float32
#  5   message0418DAA-1           float32
#  6   message0422DAA-1           float32
#  7   amscHprsovDrivF-1a         float32
#  8   amscHprsovDrivF-1b         float32
#  9   amscHprsovDrivF-2b         float32
#  10  amscPrsovDrivF-1a          float32
#  11  amscPrsovDrivF-1b          float32
#  12  amscPrsovDrivF-2b          float32
#  13  basBleedLowPressF-1a       float32
#  14  basBleedLowPressF-2b       float32
#  15  basBleedLowTempF-1a        float32
#  16  basBleedLowTempF-2b        float32
#  17  basBleedOverPressF-1a      float32
#  18  basBleedOverPressF-2b      float32
#  19  basBleedOverTempF-1a       float32
#  20  basBleedOverTempF-2b       float32
#  21  bleedFavTmCmd-1a           float32
#  22  bleedFavTmCmd-1b           float32
#  23  bleedFavTmCmd-2a           float32
#  24  bleedFavTmCmd-2b           float32
#  25  bleedFavTmFbk-1a           float32
#  26  bleedFavTmFbk-1b           float32
#  27  bleedFavTmFbk-2b           float32
#  28  bleedHprsovCmdStatus-1a    float32
#  29  bleedHprsovCmdStatus-1b    float32
#  30  bleedHprsovCmdStatus-2a    float32
#  31  bleedHprsovCmdStatus-2b    float32
#  32  bleedHprsovOpPosStatus-1a  float32
#  33  bleedHprsovOpPosStatus-1b  float32
#  34  bleedHprsovOpPosStatus-2a  float32
#  35  bleedHprsovOpPosStatus-2b  float32
#  36  bleedMonPress-1a           float32
#  37  bleedMonPress-1b           float32
#  38  bleedMonPress-2a           float32
#  39  bleedMonPress-2b           float32
#  40  bleedOnStatus-1a           float32
#  41  bleedOnStatus-1b           float32
#  42  bleedOnStatus-2b           float32
#  43  bleedOverpressCas-2a       float32
#  44  bleedOverpressCas-2b       float32
#  45  bleedPrecoolDiffPress-1a   float32
#  46  bleedPrecoolDiffPress-1b   float32
#  47  bleedPrecoolDiffPress-2a   float32
#  48  bleedPrecoolDiffPress-2b   float32
#  49  bleedPrsovClPosStatus-1a   float32
#  50  bleedPrsovClPosStatus-2a   float32
#  51  bleedPrsovFbk-1a           float32
# dtypes: float32(51), int32(1)
# memory usage: 1.4 GB

# %%
flights_combined_data_curated.describe()
# Out:
#        recording_time  dateDay-1  dateMonth-1     dateYear-1  phaseOfFlight-1  \
# count    7.376853e+06   368838.0     368838.0  368838.000000     3.689031e+06
# mean     1.983000e+06       28.0          2.0    2022.997803     8.674465e-01
# std      1.144900e+06        0.0          0.0       0.000000     9.169106e-01
# min      0.000000e+00       28.0          2.0    2023.000000     0.000000e+00
# 25%      9.915000e+05       28.0          2.0    2023.000000     0.000000e+00
# 50%      1.983000e+06       28.0          2.0    2023.000000     1.000000e+00
# 75%      2.974500e+06       28.0          2.0    2023.000000     2.000000e+00
# max      3.966000e+06       28.0          2.0    2023.000000     2.000000e+00
#
#        message0418DAA-1  message0422DAA-1  amscHprsovDrivF-1a  \
# count          368838.0          368838.0           1843911.0
# mean                0.0               0.0                 0.0
# std                 0.0               0.0                 0.0
# min                 0.0               0.0                 0.0
# 25%                 0.0               0.0                 0.0
# 50%                 0.0               0.0                 0.0
# 75%                 0.0               0.0                 0.0
# max                 0.0               0.0                 0.0
#
#        amscHprsovDrivF-1b  amscHprsovDrivF-2b  ...  bleedOnStatus-2b  \
# count           1843911.0           1843911.0  ...      3.689031e+06
# mean                  0.0                 0.0  ...      9.098999e-01
# std                   0.0                 0.0  ...      2.863251e-01
# min                   0.0                 0.0  ...      0.000000e+00
# 25%                   0.0                 0.0  ...      1.000000e+00
# 50%                   0.0                 0.0  ...      1.000000e+00
# 75%                   0.0                 0.0  ...      1.000000e+00
# max                   0.0                 0.0  ...      1.000000e+00
#
#        bleedOverpressCas-2a  bleedOverpressCas-2b  bleedPrecoolDiffPress-1a  \
# count             1843911.0             1843911.0              1.843911e+06
# mean                    0.0                   0.0              6.677172e-01
# std                     0.0                   0.0              2.672614e-01
# min                     0.0                   0.0             -2.500000e-01
# 25%                     0.0                   0.0              5.937500e-01
# 50%                     0.0                   0.0              6.875000e-01
# 75%                     0.0                   0.0              7.500000e-01
# max                     0.0                   0.0              2.781250e+00
#
#        bleedPrecoolDiffPress-1b  bleedPrecoolDiffPress-2a  \
# count              1.843911e+06              1.843911e+06
# mean               6.689526e-01              5.901328e-01
# std                2.653569e-01              2.277969e-01
# min               -2.500000e-01             -1.250000e-01
# 25%                5.937500e-01              5.625000e-01
# 50%                6.875000e-01              6.250000e-01
# 75%                7.500000e-01              6.875000e-01
# max                2.812500e+00              2.875000e+00
#
#        bleedPrecoolDiffPress-2b  bleedPrsovClPosStatus-1a  \
# count              1.843911e+06              3.689031e+06
# mean               5.901253e-01              6.622633e-02
# std                2.278252e-01              2.486773e-01
# min               -1.250000e-01              0.000000e+00
# 25%                5.625000e-01              0.000000e+00
# 50%                6.250000e-01              0.000000e+00
# 75%                6.875000e-01              0.000000e+00
# max                2.875000e+00              1.000000e+00
#
#        bleedPrsovClPosStatus-2a  bleedPrsovFbk-1a
# count              3.689031e+06      1.843911e+06
# mean               9.010008e-02      1.510177e+02
# std                2.863251e-01      4.254531e+01
# min                0.000000e+00      1.875000e+00
# 25%                0.000000e+00      1.468750e+02
# 50%                0.000000e+00      1.595000e+02
# 75%                0.000000e+00      1.680000e+02
# max                1.000000e+00      2.887500e+02
#
# [8 rows x 52 columns]

# %% [markdown]
# ### 6. Gravação do dataframe com os dados agregados em um arquivo parquet

# %%
flights_combined_data_curated.to_parquet("flights_combined_data_curated.parquet")
