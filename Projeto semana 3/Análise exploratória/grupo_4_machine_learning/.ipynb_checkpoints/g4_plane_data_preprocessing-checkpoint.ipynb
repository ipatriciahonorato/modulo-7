# %% [markdown]
# <h2><center> Pré-processamento dos dados de voo selecionados e agregados </center></h2>

# %% [markdown]
# ### 1. Importação de bliotecas

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### 2. Carregamento do arquivo de dados

# %%
flights_combined_data = pd.read_parquet('flights_combined_data.parquet')

# %%
flights_combined_data
# Out:
#         recording_time  dateDay-1  dateMonth-1  dateYear-1  phaseOfFlight-1  \
# 0                    0        NaN          NaN         NaN              0.0
# 1                   50        NaN          NaN         NaN              NaN
# 2                  100        NaN          NaN         NaN              0.0
# 3                  150       27.0          2.0      2023.0              NaN
# 4                  200        NaN          NaN         NaN              0.0
# ...                ...        ...          ...         ...              ...
# 971145         3965800       28.0          2.0      2023.0              NaN
# 971146         3965850        NaN          NaN         NaN              0.0
# 971147         3965900        NaN          NaN         NaN              NaN
# 971148         3965950        NaN          NaN         NaN              0.0
# 971149         3966000        NaN          NaN         NaN              NaN
#
# ...

# %%
flights_combined_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 971150 entries, 0 to 971149
# Data columns (total 52 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   recording_time             971150 non-null  int32
#  1   dateDay-1                  48553 non-null   float32
#  2   dateMonth-1                48553 non-null   float32
#  3   dateYear-1                 48553 non-null   float32
#  4   phaseOfFlight-1            485656 non-null  float32
#  5   message0418DAA-1           48553 non-null   float32
#  6   message0422DAA-1           48553 non-null   float32
#  7   amscHprsovDrivF-1a         242749 non-null  float32
#  8   amscHprsovDrivF-1b         242749 non-null  float32
#  9   amscHprsovDrivF-2b         242749 non-null  float32
#  10  amscPrsovDrivF-1a          242749 non-null  float32
#  11  amscPrsovDrivF-1b          242749 non-null  float32
#  12  amscPrsovDrivF-2b          242749 non-null  float32
# ...

# %%
flights_combined_data.describe()
# Out:
#        recording_time     dateDay-1  dateMonth-1    dateYear-1  \
# count    9.711500e+05  48553.000000      48553.0  48553.000000
# mean     2.518487e+06     27.461969          2.0   2023.002197
# std      1.538323e+06      0.498557          0.0      0.000000
# min      0.000000e+00     27.000000          2.0   2023.000000
# 25%      1.213900e+06     27.000000          2.0   2023.000000
# 50%      2.427850e+06     27.000000          2.0   2023.000000
# 75%      3.702550e+06     28.000000          2.0   2023.000000
# max      6.029000e+06     28.000000          2.0   2023.000000
#
#        phaseOfFlight-1  message0418DAA-1  message0422DAA-1  \
# count    485656.000000           48553.0           48553.0
# mean          0.843782               0.0               0.0
# std           0.867395               0.0               0.0
# min           0.000000               0.0               0.0
# 25%           0.000000               0.0               0.0
# ...

# %%
import seaborn as sn
import matplotlib.pyplot as plt

plt.figure(figsize = (10, 10))
corr_matrix = flights_combined_data.corr()
sn.heatmap(corr_matrix, annot=True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

def plot_all_columns(dataframe):
    for col in dataframe.columns:
        print(col)
        try:
            plt.figure(figsize=(10, 6))
            plt.plot(dataframe[col], marker='o')
            plt.title(f'Line Plot for Column: {col}')
            plt.xlabel('Index')
            plt.ylabel(col)
            plt.grid()
        except:
            print(f'Could not plot for column: {col}')
      


plot_all_columns(flights_combined_data)
plt.show()
# Out:
# recording_time
# dateDay-1
# dateMonth-1
# dateYear-1
# phaseOfFlight-1
# message0418DAA-1
# message0422DAA-1
# amscHprsovDrivF-1a
# amscHprsovDrivF-1b
# amscHprsovDrivF-2b
# amscPrsovDrivF-1a
# amscPrsovDrivF-1b
# amscPrsovDrivF-2b
# basBleedLowPressF-1a
# basBleedLowPressF-2b
# basBleedLowTempF-1a
# basBleedLowTempF-2b
# basBleedOverPressF-1a
# basBleedOverPressF-2b
# basBleedOverTempF-1a
# basBleedOverTempF-2b
# bleedFavTmCmd-1a
# bleedFavTmCmd-1b
# bleedFavTmCmd-2a
# bleedFavTmCmd-2b
# C:\Users\Inteli\AppData\Local\Temp\ipykernel_23528\2973946925.py:8: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure(figsize=(10, 6))
# bleedFavTmFbk-1a
# bleedFavTmFbk-1b
# bleedFavTmFbk-2b
# bleedHprsovCmdStatus-1a
# ...

# %%
import pandas as pd

def drop_same_value_columns(dataframe):
    columns_to_drop = []

    for col in dataframe.columns:
        if dataframe[col].nunique() == 1:
            columns_to_drop.append(col)

    if columns_to_drop:
        for col in columns_to_drop:
            print(f"Column {col} will be dropped.")

        dataframe = dataframe.drop(columns=columns_to_drop)
        print(f"{len(columns_to_drop)} columns dropped.")

    return dataframe


flights_combined_data = drop_same_value_columns(flights_combined_data)
# Out:
# Column dateMonth-1 will be dropped.
# Column dateYear-1 will be dropped.
# Column message0418DAA-1 will be dropped.
# Column message0422DAA-1 will be dropped.
# Column amscHprsovDrivF-1a will be dropped.
# Column amscHprsovDrivF-1b will be dropped.
# Column amscHprsovDrivF-2b will be dropped.
# Column amscPrsovDrivF-1a will be dropped.
# Column amscPrsovDrivF-1b will be dropped.
# Column amscPrsovDrivF-2b will be dropped.
# Column basBleedLowPressF-1a will be dropped.
# Column basBleedLowPressF-2b will be dropped.
# Column basBleedLowTempF-1a will be dropped.
# Column basBleedLowTempF-2b will be dropped.
# Column basBleedOverPressF-1a will be dropped.
# Column basBleedOverPressF-2b will be dropped.
# Column basBleedOverTempF-1a will be dropped.
# Column basBleedOverTempF-2b will be dropped.
# Column bleedOverpressCas-2a will be dropped.
# Column bleedOverpressCas-2b will be dropped.
# 20 columns dropped.

# %%
flights_combined_data
# Out:
#         recording_time  dateDay-1  phaseOfFlight-1  bleedFavTmCmd-1a  \
# 0                    0        NaN              0.0               NaN
# 1                   50        NaN              NaN               0.0
# 2                  100        NaN              0.0               NaN
# 3                  150       27.0              NaN               NaN
# 4                  200        NaN              0.0               NaN
# ...                ...        ...              ...               ...
# 971145         3965800       28.0              NaN               NaN
# 971146         3965850        NaN              0.0               NaN
# 971147         3965900        NaN              NaN               0.0
# 971148         3965950        NaN              0.0               NaN
# 971149         3966000        NaN              NaN               NaN
#
#         bleedFavTmCmd-1b  bleedFavTmCmd-2a  bleedFavTmCmd-2b  \
# 0                    NaN               NaN               NaN
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

def plot_all_columns(dataframe):
    for col in dataframe.columns:
        try:
            plt.figure(figsize=(10, 6))
            plt.plot(dataframe[col], marker='o')
            plt.title(f'Line Plot for Column: {col}')
            plt.xlabel('Index')
            plt.ylabel(col)
            plt.grid()
        except:
            print(f'Could not plot for column: {col}')
      


plot_all_columns(flights_combined_data)
plt.show()
# Out:
# C:\Users\Inteli\AppData\Local\Temp\ipykernel_2960\24836451.py:7: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure(figsize=(10, 6))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[185], line 19
#      14             print(f'Could not plot for column: {col}')
#      18 plot_all_columns(flights_combined_data)
# ---> 19 plt.show()
#
# File c:\Users\Inteli\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\pyplot.py:446, in show(*args, **kwargs)
#     402 """
#     403 Display all open figures.
#     404
#    (...)
#     443 explicitly there.
#     444 """
# ...

# %%
import seaborn as sn
import matplotlib.pyplot as plt

plt.figure(figsize = (10, 10))
corr_matrix = flights_combined_data.corr()
sn.heatmap(corr_matrix, annot=True)
plt.show()
